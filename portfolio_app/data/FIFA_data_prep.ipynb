# %%
import pandas as pd
import numpy as np
from pandas.api.types import infer_dtype
import sqlite3
from tqdm import tqdm
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)

class FIFA_Processing:
    
    def __init__(self, database_name, table_name, process_from_scratch):

        self.database_name  = database_name
        self.table_name     = table_name
        self.from_scratch   = process_from_scratch

        self.sysdata   = ["sofifa_id",  'real_face', 'player_url', 'year']
        self.constants = ['short_name','long_name', 'dob']
        self.variables = ["value_eur", 'nation_position', 'club_name', 'potential', 'wage_eur', 'international_reputation',
                          'release_clause_eur', 'loaned_from', 'weight_kg', 'league_name', 'contract_valid_until', 'player_positions',
                          'height_cm', 'preferred_foot', 'team_position', 'work_rate', 'joined', 'age', 'body_type',
                          'team_jersey_number', 'league_rank', 'nation_jersey_number', 'nationality', 'player_tags', 'player_traits']
        self.abilities = ['overall', 'shooting', 'dribbling', 'mentality_positioning', 'goalkeeping_positioning', 'goalkeeping_diving',
                          'goalkeeping_kicking', 'gk_speed', 'goalkeeping_handling', 'skill_moves', 'skill_ball_control',
                          'defending', 'gk_positioning', 'gk_reflexes', 'attacking_volleys', 'weak_foot', 'power_long_shots',
                          'movement_reactions', 'movement_balance', 'defending_standing_tackle', 'gk_diving', 'movement_acceleration',
                          'attacking_finishing', 'movement_sprint_speed', 'skill_curve', 'mentality_composure', 'skill_dribbling',
                          'mentality_aggression', 'attacking_heading_accuracy', 'gk_handling', 'power_shot_power', 'mentality_vision',
                          'goalkeeping_reflexes', 'passing', 'mentality_interceptions', 'pace', 'skill_long_passing', 'defending_marking',
                          'power_strength', 'defending_sliding_tackle', 'attacking_short_passing', 'physic', 'mentality_penalties',
                          'gk_kicking', 'skill_fk_accuracy', 'power_stamina',  'movement_agility', 'power_jumping', 'attacking_crossing']
        self.positions = ['cf','lb','ls','lm','rs','cb','rf','st','rm','lf','cm','rw','rb','lw',
                          'lcb','cam','rdm','lcm','ldm','rcm','rcb','rwb','lwb','ram','lam','cdm']
        self.to_remove = ["player_traits", "player_tags"]
        self.semantics = {}
        for i in "sysdata", "constants", "variables", "positions", "abilities", :
            for k in eval(f"self.{i}"):
                self.semantics[k] = i
        
        if self.from_scratch == True:
            self.import_data()
            self.data_quality_fix()
            self.apply_tags()
            self.apply_traits()
            self.replace_nulls()
            self.upload_to_database()
        
    def get_metadata(self, df):
        meta = pd.DataFrame({
            "colname"       : [i for i in df.columns],
            "count"         : [len(df[i]) for i in df.columns],
            "null_count"    : [df[i].isnull().sum() for i in df.columns],
            "data_type"     : [infer_dtype(df[i]) for i in df.columns]
        })
        return meta
    
    def import_data(self):
        print("Importing data")
        self.data = {}
        for year in np.arange(15, 22):
            self.data[f"df_{str(year)}"] = {"df": pd.read_csv(f"players_{str(year)}.csv")}
            self.data[f"df_{str(year)}"]["df"]["year"] = int("20" + str(year))
        print("Successfully imported data\n")
    
    def data_quality_fix(self):
        print("Applying data quality fixes")
        for year in np.arange(15, 22):
            df = self.data[f"df_{str(year)}"]["df"]
            try:
                main_df = pd.concat([main_df, df[main_df.columns]], axis = 0).reset_index(drop=True)
            except:
                main_df = df.copy()
        group_cols  = ["long_name","short_name","player_url","dob","real_face"]
        checking_df = main_df[self.sysdata + self.constants]
        master      = checking_df.groupby(["sofifa_id"])[group_cols].agg("max")[group_cols].drop_duplicates().reset_index(drop=False)
        master_df   = pd.merge(left = main_df.drop(group_cols, axis = 1), right = master,
                               left_on = "sofifa_id", right_on = "sofifa_id", how = "left")
        self.master_df = master_df.copy()[~pd.isnull(master_df["club_name"])]
        for colname in ["short_name", "long_name", "club_name", "league_name", "loaned_from"]:
            self.master_df[colname] = self.master_df[colname].apply(lambda x: x.replace("'", ""))
        print("Successfully applied data quality fixes\n")

    def apply_tags(self):
        print("Applying transformation to 'player_tags'")
        all_tags = []
        logic = lambda x: [k.replace("#", "").strip().replace(" ", "_") for k in str(x).split(",")]
        for i in self.master_df["player_tags"]:
            if not pd.isnull(i):
                all_tags.extend(logic(i))
        all_tags = list(set(all_tags))
        self.master_df["player_tags"] = self.master_df["player_tags"].apply(lambda x: logic(x))
        for tagname in all_tags:
            self.master_df[f"tag_{tagname}"] = self.master_df["player_tags"].apply(lambda x: 1 if tagname in x else 0)
        self.master_df = self.master_df.drop(["player_tags"], axis = 1)
        print("Successfully applied transformation to 'player_tags'\n")

    def apply_traits(self):
        print("Applying transformation to 'player_traits'")
        all_traits = []
        logic = lambda x: [k.replace("(AI)", "").strip().replace(" ","_").replace("-","") for k in str(x).split(",")]
        for i in self.master_df["player_traits"]:
            if not pd.isnull(i):
                all_traits.extend(logic(i))
        all_traits = list(set(all_traits))
        self.master_df["player_traits"] = self.master_df["player_traits"].apply(lambda x: logic(x))
        for traitname in all_traits:
            self.master_df[f"trait_{traitname}"] = self.master_df["player_traits"].apply(lambda x: 1 if traitname in x else 0)
        self.master_df = self.master_df.drop(["player_traits"], axis = 1)
        print("Successfully applied transformation to 'player_traits'\n")

    def replace_nulls(self):
        print("Replacing null values")
        null_replacements = {
            "nation_position" : "NA",
            "nation_jersey_number" : "NA",
            "loaned_from" : "NA"
        }
        for k, v in list(null_replacements.items()):
            self.master_df[k] = self.master_df[k].apply(lambda x: v if pd.isnull(x) else x)
        self.master_df["has_release_clause"] = self.master_df["release_clause_eur"].apply(lambda x: "No" if pd.isnull(x) else "Yes")
        print("Successfully replaced null values\n")

    def create_sql_statement(self):
        statement = ""
        type_refs = {"integer" : "INTEGER", "floating": "FLOAT", "string": "TEXT", "mixed": "TEXT"}
        generate_sql_statement = lambda x: f"{x['colname']} {type_refs[x['data_type']]}"
        meta = self.get_metadata(self.master_df)
        meta["sql_statement"] = meta.apply(lambda x: generate_sql_statement(x), axis = 1)
        statement += f"CREATE TABLE IF NOT EXISTS {self.table_name} ("
        for eachrow in range(len(meta)):
            statement += f"{meta.loc[eachrow, 'sql_statement']}, "
        statement = statement.strip()[:-1].strip()
        statement += ");"
        return statement

    def insert_sql_statement(self, x):
        statement = f"INSERT INTO {self.table_name} VALUES ("
        for i in x:
            statement += f"'{i}', "
        statement = statement.strip()[:-1].strip() + ");"
        return statement
    
    def upload_to_database(self):
        self.failed_attempts = []
        connection = sqlite3.connect(self.database_name)
        cursor = connection.cursor()
        if self.from_scratch == True:
            print("Dropping table")
            cursor.execute(f"DROP TABLE IF EXISTS {self.table_name};")
            print("Successfully dropped table\n")
        print("Creating table")
        cursor.execute(self.create_sql_statement())
        print("Successfully created table\n")
        print("Inserting data into table")
        for i in tqdm(range(len(self.master_df))):
            try:
                cursor.execute(self.insert_sql_statement(self.master_df.iloc[i, :]))
                connection.commit()
            except:
                self.failed_attempts.append(self.master_df.iloc[i, :])
        print("Successfully inserted data into table\n")
        connection.commit()
        connection.close()

# %%
FIFA = FIFA_Processing(
    database_name = "fifa.db",
    table_name = "players",
    process_from_scratch = True
)
# Out:
# Importing data
# Successfully imported data
#
# Applying data quality fixes
# Successfully applied data quality fixes
#
# Applying transformation to 'player_tags'
# Successfully applied transformation to 'player_tags'
#
# Applying transformation to 'player_traits'
# Successfully applied transformation to 'player_traits'
#
# Replacing null values
# Successfully replaced null values
#
# Dropping table
# Successfully dropped table
#
# Creating table
# Successfully created table
#
# Inserting data into table
# 100%|██████████| 121272/121272 [00:48<00:00, 2484.73it/s]
# Successfully inserted data into table

# %%
for i in FIFA.failed_attempts:
    print(i)
# Out:
# sofifa_id                                                                     199043
# age                                                                               31
# height_cm                                                                        188
# weight_kg                                                                         87
# nationality                                                                    Chile
# club_name                                                       Universidad de Chile
# league_name                                              Chilian Campeonato Nacional
# league_rank                                                                      1.0
# overall                                                                           69
# potential                                                                         69
# value_eur                                                                     850000
# wage_eur                                                                       15000
# player_positions                                                                  GK
# preferred_foot                                                                 Right
# international_reputation                                                           1
# weak_foot                                                                          3
# skill_moves                                                                        1
# work_rate                                                              Medium/Medium
# body_type                                                                     Normal
# release_clause_eur                                                               NaN
# team_position                                                                    SUB
# team_jersey_number                                                               1.0
# loaned_from                                                             CD O'Higgins
# joined                                                                           NaN
# contract_valid_until                                                          2015.0
# nation_position                                                                   NA
# nation_jersey_number                                                              NA
# pace                                                                             NaN
# shooting                                                                         NaN
# passing                                                                          NaN
# dribbling                                                                        NaN
# defending                                                                        NaN
# physic                                                                           NaN
# gk_diving                                                                       70.0
# gk_handling                                                                     71.0
# gk_kicking                                                                      73.0
# gk_reflexes                                                                     72.0
# gk_speed                                                                        34.0
# gk_positioning                                                                  67.0
# attacking_crossing                                                                25
# attacking_finishing                                                               25
# attacking_heading_accuracy                                                        25
# attacking_short_passing                                                           21
# attacking_volleys                                                                 25
# skill_dribbling                                                                   25
# skill_curve                                                                       25
# skill_fk_accuracy                                                                 25
# skill_long_passing                                                                22
# skill_ball_control                                                                25
# movement_acceleration                                                             36
# movement_sprint_speed                                                             33
# movement_agility                                                                  62
# movement_reactions                                                                48
# movement_balance                                                                  31
# power_shot_power                                                                  38
# power_jumping                                                                     79
# power_stamina                                                                     25
# power_strength                                                                    76
# power_long_shots                                                                  25
# mentality_aggression                                                              26
# mentality_interceptions                                                           20
# mentality_positioning                                                             25
# mentality_vision                                                                  25
# mentality_penalties                                                               33
# mentality_composure                                                              NaN
# defending_marking                                                               25.0
# defending_standing_tackle                                                         25
# defending_sliding_tackle                                                          25
# goalkeeping_diving                                                                70
# goalkeeping_handling                                                              71
# goalkeeping_kicking                                                               73
# goalkeeping_positioning                                                           67
# goalkeeping_reflexes                                                              72
# ls                                                                              31+0
# st                                                                              31+0
# rs                                                                              31+0
# lw                                                                              29+0
# lf                                                                              29+0
# cf                                                                              29+0
# rf                                                                              29+0
# rw                                                                              29+0
# lam                                                                             29+0
# cam                                                                             29+0
# ram                                                                             29+0
# lm                                                                              28+0
# lcm                                                                             25+0
# cm                                                                              25+0
# rcm                                                                             25+0
# rm                                                                              28+0
# lwb                                                                             27+0
# ldm                                                                             29+0
# cdm                                                                             29+0
# rdm                                                                             29+0
# rwb                                                                             27+0
# lb                                                                              26+0
# lcb                                                                             33+0
# cb                                                                              33+0
# rcb                                                                             33+0
# rb                                                                              26+0
# year                                                                            2015
# long_name                                                Luis Antonio Marín Barahona
# short_name                                                                  L. Marín
# player_url                        https://sofifa.com/player/199043/luis-marin/170002
# dob                                                                       1983-05-18
# real_face                                                                         No
# tag_Complete_Midfielder                                                            0
# tag_Acrobat                                                                        0
# tag_Aerial_Threat                                                                  0
# tag_Dribbler                                                                       0
# tag_Tactician                                                                      0
# tag_Distance_Shooter                                                               0
# tag_Clinical_Finisher                                                              0
# tag_Tackling                                                                       0
# tag_Complete_Defender                                                              0
# tag_Strength                                                                       0
# tag_Playmaker                                                                      0
# tag_Engine                                                                         0
# tag_Crosser                                                                        0
# tag_Poacher                                                                        0
# tag_Complete_Forward                                                               0
# tag_Speedster                                                                      0
# tag_FK_Specialist                                                                  0
# trait_Rushes_Out_Of_Goal                                                           0
# trait_Team_Player                                                                  0
# trait_GK_Long_Throw                                                                0
# trait_Speed_Dribbler                                                               0
# trait_Comes_For_Crosses                                                            0
# trait_GK_Up_for_Corners                                                            0
# trait_Through_Ball                                                                 0
# trait_Giant_Throwin                                                                0
# trait_Injury_Free                                                                  0
# trait_Outside_Foot_Shot                                                            0
# trait_Backs_Into_Player                                                            0
# trait_Injury_Prone                                                                 0
# trait_Power_FreeKick                                                               0
# trait_Swerve_Pass                                                                  0
# trait_Power_Header                                                                 0
# trait_Cautious_With_Crosses                                                        0
# trait_Early_Crosser                                                                0
# trait_1on1_Rush                                                                    0
# trait_Playmaker                                                                    0
# trait_Long_Passer                                                                  0
# trait_One_Club_Player                                                              0
# trait_Leadership                                                                   0
# trait_Set_Play_Specialist                                                          0
# trait_Long_Throwin                                                                 0
# trait_Dives_Into_Tackles                                                           0
# trait_Puncher                                                                      1
# trait_Flair                                                                        0
# trait_Technical_Dribbler                                                           0
# trait_Saves_with_Feet                                                              0
# trait_Chip_Shot                                                                    0
# trait_Selfish                                                                      0
# trait_Target_Forward                                                               0
# trait_Beat_Offside_Trap                                                            0
# trait_Avoids_Using_Weaker_Foot                                                     0
# trait_Takes_Finesse_Free_Kicks                                                     0
# trait_Long_Shot_Taker                                                              0
# trait_Diver                                                                        0
# trait_Finesse_Shot                                                                 0
# trait_Solid_Player                                                                 0
# has_release_clause                                                                No
# Name: 3911, dtype: object
# sofifa_id                                                                          214266
# age                                                                                    29
# height_cm                                                                             175
# weight_kg                                                                              74
# nationality                                                                         Chile
# club_name                                                              Santiago Wanderers
# league_name                                                   Chilian Campeonato Nacional
# league_rank                                                                           1.0
# overall                                                                                65
# potential                                                                              65
# value_eur                                                                          475000
# wage_eur                                                                             5000
# player_positions                                                                   LM, LB
# preferred_foot                                                                       Left
# international_reputation                                                                1
# weak_foot                                                                               2
# skill_moves                                                                             2
# work_rate                                                                   Medium/Medium
# body_type                                                                          Stocky
# release_clause_eur                                                                    NaN
# team_position                                                                          LM
# team_jersey_number                                                                   13.0
# loaned_from                                                                  CD O'Higgins
# joined                                                                                NaN
# contract_valid_until                                                               2015.0
# nation_position                                                                        NA
# nation_jersey_number                                                                   NA
# pace                                                                                 70.0
# shooting                                                                             68.0
# passing                                                                              64.0
# dribbling                                                                            67.0
# defending                                                                            44.0
# physic                                                                               64.0
# gk_diving                                                                             NaN
# gk_handling                                                                           NaN
# gk_kicking                                                                            NaN
# gk_reflexes                                                                           NaN
# gk_speed                                                                              NaN
# gk_positioning                                                                        NaN
# attacking_crossing                                                                     63
# attacking_finishing                                                                    66
# attacking_heading_accuracy                                                             48
# attacking_short_passing                                                                67
# attacking_volleys                                                                      61
# skill_dribbling                                                                        67
# skill_curve                                                                            61
# skill_fk_accuracy                                                                      63
# skill_long_passing                                                                     64
# skill_ball_control                                                                     67
# movement_acceleration                                                                  67
# movement_sprint_speed                                                                  72
# movement_agility                                                                       74
# movement_reactions                                                                     53
# movement_balance                                                                       67
# power_shot_power                                                                       74
# power_jumping                                                                          69
# power_stamina                                                                          68
# power_strength                                                                         67
# power_long_shots                                                                       70
# mentality_aggression                                                                   52
# mentality_interceptions                                                                52
# mentality_positioning                                                                  69
# mentality_vision                                                                       60
# mentality_penalties                                                                    59
# mentality_composure                                                                   NaN
# defending_marking                                                                    37.0
# defending_standing_tackle                                                              41
# defending_sliding_tackle                                                               49
# goalkeeping_diving                                                                      6
# goalkeeping_handling                                                                    6
# goalkeeping_kicking                                                                     9
# goalkeeping_positioning                                                                 9
# goalkeeping_reflexes                                                                   14
# ls                                                                                   64+0
# st                                                                                   64+0
# rs                                                                                   64+0
# lw                                                                                    66+
# lf                                                                                    66+
# cf                                                                                    66+
# rf                                                                                    66+
# rw                                                                                    66+
# lam                                                                                   66+
# cam                                                                                   66+
# ram                                                                                   66+
# lm                                                                                   65+0
# lcm                                                                                  62+0
# cm                                                                                   62+0
# rcm                                                                                  62+0
# rm                                                                                   65+0
# lwb                                                                                  57+0
# ldm                                                                                  57+0
# cdm                                                                                  57+0
# rdm                                                                                  57+0
# rwb                                                                                  57+0
# lb                                                                                   54+0
# lcb                                                                                  51+0
# cb                                                                                   51+0
# rcb                                                                                  51+0
# rb                                                                                   54+0
# year                                                                                 2015
# long_name                                                  Gonzalo Felipe Barriga Ahumada
# short_name                                                                     G. Barriga
# player_url                        https://sofifa.com/player/214266/gonzalo-barriga/190002
# dob                                                                            1984-07-21
# real_face                                                                              No
# tag_Complete_Midfielder                                                                 0
# tag_Acrobat                                                                             0
# tag_Aerial_Threat                                                                       0
# tag_Dribbler                                                                            0
# tag_Tactician                                                                           0
# tag_Distance_Shooter                                                                    0
# tag_Clinical_Finisher                                                                   0
# tag_Tackling                                                                            0
# tag_Complete_Defender                                                                   0
# tag_Strength                                                                            0
# tag_Playmaker                                                                           0
# tag_Engine                                                                              0
# tag_Crosser                                                                             0
# tag_Poacher                                                                             0
# tag_Complete_Forward                                                                    0
# tag_Speedster                                                                           0
# tag_FK_Specialist                                                                       0
# trait_Rushes_Out_Of_Goal                                                                0
# trait_Team_Player                                                                       0
# trait_GK_Long_Throw                                                                     0
# trait_Speed_Dribbler                                                                    0
# trait_Comes_For_Crosses                                                                 0
# trait_GK_Up_for_Corners                                                                 0
# trait_Through_Ball                                                                      0
# trait_Giant_Throwin                                                                     0
# trait_Injury_Free                                                                       0
# trait_Outside_Foot_Shot                                                                 0
# trait_Backs_Into_Player                                                                 0
# trait_Injury_Prone                                                                      0
# trait_Power_FreeKick                                                                    0
# trait_Swerve_Pass                                                                       0
# trait_Power_Header                                                                      0
# trait_Cautious_With_Crosses                                                             0
# trait_Early_Crosser                                                                     0
# trait_1on1_Rush                                                                         0
# trait_Playmaker                                                                         0
# trait_Long_Passer                                                                       0
# trait_One_Club_Player                                                                   0
# trait_Leadership                                                                        0
# trait_Set_Play_Specialist                                                               0
# trait_Long_Throwin                                                                      0
# trait_Dives_Into_Tackles                                                                0
# trait_Puncher                                                                           0
# trait_Flair                                                                             0
# trait_Technical_Dribbler                                                                0
# trait_Saves_with_Feet                                                                   0
# trait_Chip_Shot                                                                         0
# trait_Selfish                                                                           0
# trait_Target_Forward                                                                    0
# trait_Beat_Offside_Trap                                                                 0
# trait_Avoids_Using_Weaker_Foot                                                          0
# trait_Takes_Finesse_Free_Kicks                                                          0
# trait_Long_Shot_Taker                                                                   0
# trait_Diver                                                                             0
# trait_Finesse_Shot                                                                      0
# trait_Solid_Player                                                                      0
# has_release_clause                                                                     No
# Name: 7260, dtype: object
# sofifa_id                                                                        214698
# age                                                                                  21
# height_cm                                                                           182
# weight_kg                                                                            78
# nationality                                                                       Chile
# club_name                                                               Unión La Calera
# league_name                                                 Chilian Campeonato Nacional
# league_rank                                                                         1.0
# overall                                                                              62
# potential                                                                            70
# value_eur                                                                        230000
# wage_eur                                                                           4000
# player_positions                                                                     CB
# preferred_foot                                                                    Right
# international_reputation                                                              1
# weak_foot                                                                             2
# skill_moves                                                                           2
# work_rate                                                                      Low/High
# body_type                                                                        Stocky
# release_clause_eur                                                                  NaN
# team_position                                                                       RCB
# team_jersey_number                                                                  5.0
# loaned_from                                                                CD O'Higgins
# joined                                                                              NaN
# contract_valid_until                                                             2015.0
# nation_position                                                                      NA
# nation_jersey_number                                                                 NA
# pace                                                                               51.0
# shooting                                                                           36.0
# passing                                                                            50.0
# dribbling                                                                          45.0
# defending                                                                          60.0
# physic                                                                             70.0
# gk_diving                                                                           NaN
# gk_handling                                                                         NaN
# gk_kicking                                                                          NaN
# gk_reflexes                                                                         NaN
# gk_speed                                                                            NaN
# gk_positioning                                                                      NaN
# attacking_crossing                                                                   49
# attacking_finishing                                                                  32
# attacking_heading_accuracy                                                           59
# attacking_short_passing                                                              61
# attacking_volleys                                                                    36
# skill_dribbling                                                                      43
# skill_curve                                                                          41
# skill_fk_accuracy                                                                    39
# skill_long_passing                                                                   48
# skill_ball_control                                                                   48
# movement_acceleration                                                                48
# movement_sprint_speed                                                                54
# movement_agility                                                                     38
# movement_reactions                                                                   60
# movement_balance                                                                     51
# power_shot_power                                                                     48
# power_jumping                                                                        56
# power_stamina                                                                        60
# power_strength                                                                       78
# power_long_shots                                                                     30
# mentality_aggression                                                                 67
# mentality_interceptions                                                              54
# mentality_positioning                                                                39
# mentality_vision                                                                     37
# mentality_penalties                                                                  47
# mentality_composure                                                                 NaN
# defending_marking                                                                  63.0
# defending_standing_tackle                                                            61
# defending_sliding_tackle                                                             60
# goalkeeping_diving                                                                    7
# goalkeeping_handling                                                                 12
# goalkeeping_kicking                                                                  14
# goalkeeping_positioning                                                               6
# goalkeeping_reflexes                                                                 11
# ls                                                                                 45+0
# st                                                                                 45+0
# rs                                                                                 45+0
# lw                                                                                 47+0
# lf                                                                                 45+0
# cf                                                                                 45+0
# rf                                                                                 45+0
# rw                                                                                 47+0
# lam                                                                                45+0
# cam                                                                                45+0
# ram                                                                                45+0
# lm                                                                                 49+0
# lcm                                                                                50+0
# cm                                                                                 50+0
# rcm                                                                                50+0
# rm                                                                                 49+0
# lwb                                                                                55+0
# ldm                                                                                57+0
# cdm                                                                                57+0
# rdm                                                                                57+0
# rwb                                                                                55+0
# lb                                                                                 58+0
# lcb                                                                                62+0
# cb                                                                                 62+0
# rcb                                                                                62+0
# rb                                                                                 58+0
# year                                                                               2015
# long_name                                                Luis Ignacio Casanova Sandoval
# short_name                                                                  L. Casanova
# player_url                        https://sofifa.com/player/214698/luis-casanova/190002
# dob                                                                          1992-07-01
# real_face                                                                            No
# tag_Complete_Midfielder                                                               0
# tag_Acrobat                                                                           0
# tag_Aerial_Threat                                                                     0
# tag_Dribbler                                                                          0
# tag_Tactician                                                                         0
# tag_Distance_Shooter                                                                  0
# tag_Clinical_Finisher                                                                 0
# tag_Tackling                                                                          0
# tag_Complete_Defender                                                                 0
# tag_Strength                                                                          0
# tag_Playmaker                                                                         0
# tag_Engine                                                                            0
# tag_Crosser                                                                           0
# tag_Poacher                                                                           0
# tag_Complete_Forward                                                                  0
# tag_Speedster                                                                         0
# tag_FK_Specialist                                                                     0
# trait_Rushes_Out_Of_Goal                                                              0
# trait_Team_Player                                                                     0
# trait_GK_Long_Throw                                                                   0
# trait_Speed_Dribbler                                                                  0
# trait_Comes_For_Crosses                                                               0
# trait_GK_Up_for_Corners                                                               0
# trait_Through_Ball                                                                    0
# trait_Giant_Throwin                                                                   0
# trait_Injury_Free                                                                     0
# trait_Outside_Foot_Shot                                                               0
# trait_Backs_Into_Player                                                               0
# trait_Injury_Prone                                                                    0
# trait_Power_FreeKick                                                                  0
# trait_Swerve_Pass                                                                     0
# trait_Power_Header                                                                    0
# trait_Cautious_With_Crosses                                                           0
# trait_Early_Crosser                                                                   0
# trait_1on1_Rush                                                                       0
# trait_Playmaker                                                                       0
# trait_Long_Passer                                                                     0
# trait_One_Club_Player                                                                 0
# trait_Leadership                                                                      0
# trait_Set_Play_Specialist                                                             0
# trait_Long_Throwin                                                                    0
# trait_Dives_Into_Tackles                                                              0
# trait_Puncher                                                                         0
# trait_Flair                                                                           0
# trait_Technical_Dribbler                                                              0
# trait_Saves_with_Feet                                                                 0
# trait_Chip_Shot                                                                       0
# trait_Selfish                                                                         0
# trait_Target_Forward                                                                  0
# trait_Beat_Offside_Trap                                                               0
# trait_Avoids_Using_Weaker_Foot                                                        0
# trait_Takes_Finesse_Free_Kicks                                                        0
# trait_Long_Shot_Taker                                                                 0
# trait_Diver                                                                           0
# trait_Finesse_Shot                                                                    0
# trait_Solid_Player                                                                    0
# has_release_clause                                                                   No
# Name: 9458, dtype: object
# sofifa_id                                                                          214263
# age                                                                                    26
# height_cm                                                                             176
# weight_kg                                                                              75
# nationality                                                                         Chile
# club_name                                                                  Audax Italiano
# league_name                                                   Chilian Campeonato Nacional
# league_rank                                                                           1.0
# overall                                                                                62
# potential                                                                              64
# value_eur                                                                          300000
# wage_eur                                                                             5000
# player_positions                                                                  CDM, CM
# preferred_foot                                                                      Right
# international_reputation                                                                1
# weak_foot                                                                               3
# skill_moves                                                                             2
# work_rate                                                                   Medium/Medium
# body_type                                                                          Normal
# release_clause_eur                                                                    NaN
# team_position                                                                         LCB
# team_jersey_number                                                                   14.0
# loaned_from                                                                  CD O'Higgins
# joined                                                                                NaN
# contract_valid_until                                                               2014.0
# nation_position                                                                        NA
# nation_jersey_number                                                                   NA
# pace                                                                                 61.0
# shooting                                                                             51.0
# passing                                                                              61.0
# dribbling                                                                            63.0
# defending                                                                            61.0
# physic                                                                               73.0
# gk_diving                                                                             NaN
# gk_handling                                                                           NaN
# gk_kicking                                                                            NaN
# gk_reflexes                                                                           NaN
# gk_speed                                                                              NaN
# gk_positioning                                                                        NaN
# attacking_crossing                                                                     59
# attacking_finishing                                                                    37
# attacking_heading_accuracy                                                             48
# attacking_short_passing                                                                67
# attacking_volleys                                                                      63
# skill_dribbling                                                                        61
# skill_curve                                                                            59
# skill_fk_accuracy                                                                      61
# skill_long_passing                                                                     73
# skill_ball_control                                                                     63
# movement_acceleration                                                                  64
# movement_sprint_speed                                                                  58
# movement_agility                                                                       77
# movement_reactions                                                                     50
# movement_balance                                                                       64
# power_shot_power                                                                       64
# power_jumping                                                                          66
# power_stamina                                                                          78
# power_strength                                                                         70
# power_long_shots                                                                       61
# ...
# trait_Saves_with_Feet                                                                      0
# trait_Chip_Shot                                                                            0
# trait_Selfish                                                                              0
# trait_Target_Forward                                                                       0
# trait_Beat_Offside_Trap                                                                    0
# trait_Avoids_Using_Weaker_Foot                                                             0
# trait_Takes_Finesse_Free_Kicks                                                             0
# trait_Long_Shot_Taker                                                                      0
# trait_Diver                                                                                0
# trait_Finesse_Shot                                                                         0
# trait_Solid_Player                                                                         0
# has_release_clause                                                                        No
# Name: 98615, dtype: object
# sofifa_id                                                                           245851
# age                                                                                     21
# height_cm                                                                              183
# weight_kg                                                                               70
# nationality                                                                      Argentina
# club_name                                                              Patriotas Boyacá FC
# league_name                                                        Colombian Liga Postobón
# league_rank                                                                            1.0
# overall                                                                                 58
# potential                                                                               69
# value_eur                                                                           210000
# wage_eur                                                                               500
# player_positions                                                                        CM
# preferred_foot                                                                       Right
# international_reputation                                                                 1
# weak_foot                                                                                3
# skill_moves                                                                              3
# work_rate                                                                    Medium/Medium
# body_type                                                                             Lean
# release_clause_eur                                                                     NaN
# team_position                                                                          RES
# team_jersey_number                                                                    30.0
# loaned_from                                                              Newell's Old Boys
# joined                                                                                 NaN
# contract_valid_until                                                                2019.0
# nation_position                                                                         NA
# nation_jersey_number                                                                    NA
# pace                                                                                  61.0
# shooting                                                                              52.0
# passing                                                                               59.0
# dribbling                                                                             63.0
# defending                                                                             51.0
# physic                                                                                56.0
# gk_diving                                                                              NaN
# gk_handling                                                                            NaN
# gk_kicking                                                                             NaN
# gk_reflexes                                                                            NaN
# gk_speed                                                                               NaN
# gk_positioning                                                                         NaN
# attacking_crossing                                                                      55
# attacking_finishing                                                                     52
# attacking_heading_accuracy                                                              62
# attacking_short_passing                                                                 64
# attacking_volleys                                                                       50
# skill_dribbling                                                                         65
# skill_curve                                                                             58
# skill_fk_accuracy                                                                       51
# skill_long_passing                                                                      58
# skill_ball_control                                                                      62
# movement_acceleration                                                                   62
# movement_sprint_speed                                                                   60
# movement_agility                                                                        60
# movement_reactions                                                                      54
# movement_balance                                                                        61
# power_shot_power                                                                        64
# power_jumping                                                                           60
# power_stamina                                                                           53
# power_strength                                                                          60
# power_long_shots                                                                        40
# mentality_aggression                                                                    47
# mentality_interceptions                                                                 36
# mentality_positioning                                                                   53
# mentality_vision                                                                        57
# mentality_penalties                                                                     52
# mentality_composure                                                                   61.0
# defending_marking                                                                      NaN
# defending_standing_tackle                                                               58
# defending_sliding_tackle                                                                61
# goalkeeping_diving                                                                       8
# goalkeeping_handling                                                                    10
# goalkeeping_kicking                                                                      8
# goalkeeping_positioning                                                                  8
# goalkeeping_reflexes                                                                    10
# ls                                                                                    58+2
# st                                                                                    58+2
# rs                                                                                    58+2
# lw                                                                                    58+0
# lf                                                                                    58+0
# cf                                                                                    58+0
# rf                                                                                    58+0
# rw                                                                                    58+0
# lam                                                                                   59+2
# cam                                                                                   59+2
# ram                                                                                   59+2
# lm                                                                                    59+2
# lcm                                                                                   57+2
# cm                                                                                    57+2
# rcm                                                                                   57+2
# rm                                                                                    59+2
# lwb                                                                                   55+2
# ldm                                                                                   54+2
# cdm                                                                                   54+2
# rdm                                                                                   54+2
# rwb                                                                                   55+2
# lb                                                                                    55+2
# lcb                                                                                   54+2
# cb                                                                                    54+2
# rcb                                                                                   54+2
# rb                                                                                    55+2
# year                                                                                  2020
# long_name                                                                 Lisandro Cabrera
# short_name                                                                      L. Cabrera
# player_url                        https://sofifa.com/player/245851/lisandro-cabrera/200002
# dob                                                                             1998-01-04
# real_face                                                                               No
# tag_Complete_Midfielder                                                                  0
# tag_Acrobat                                                                              0
# tag_Aerial_Threat                                                                        0
# tag_Dribbler                                                                             0
# tag_Tactician                                                                            0
# tag_Distance_Shooter                                                                     0
# tag_Clinical_Finisher                                                                    0
# tag_Tackling                                                                             0
# tag_Complete_Defender                                                                    0
# tag_Strength                                                                             0
# tag_Playmaker                                                                            0
# tag_Engine                                                                               0
# tag_Crosser                                                                              0
# tag_Poacher                                                                              0
# tag_Complete_Forward                                                                     0
# tag_Speedster                                                                            0
# tag_FK_Specialist                                                                        0
# trait_Rushes_Out_Of_Goal                                                                 0
# trait_Team_Player                                                                        0
# trait_GK_Long_Throw                                                                      0
# trait_Speed_Dribbler                                                                     0
# trait_Comes_For_Crosses                                                                  0
# trait_GK_Up_for_Corners                                                                  0
# trait_Through_Ball                                                                       0
# trait_Giant_Throwin                                                                      0
# trait_Injury_Free                                                                        0
# trait_Outside_Foot_Shot                                                                  0
# trait_Backs_Into_Player                                                                  0
# trait_Injury_Prone                                                                       0
# trait_Power_FreeKick                                                                     0
# trait_Swerve_Pass                                                                        0
# trait_Power_Header                                                                       0
# trait_Cautious_With_Crosses                                                              0
# trait_Early_Crosser                                                                      0
# trait_1on1_Rush                                                                          0
# trait_Playmaker                                                                          0
# trait_Long_Passer                                                                        0
# trait_One_Club_Player                                                                    0
# trait_Leadership                                                                         0
# trait_Set_Play_Specialist                                                                0
# trait_Long_Throwin                                                                       0
# trait_Dives_Into_Tackles                                                                 0
# trait_Puncher                                                                            0
# trait_Flair                                                                              0
# trait_Technical_Dribbler                                                                 0
# trait_Saves_with_Feet                                                                    0
# trait_Chip_Shot                                                                          0
# trait_Selfish                                                                            0
# trait_Target_Forward                                                                     0
# trait_Beat_Offside_Trap                                                                  0
# trait_Avoids_Using_Weaker_Foot                                                           0
# trait_Takes_Finesse_Free_Kicks                                                           0
# trait_Long_Shot_Taker                                                                    0
# trait_Diver                                                                              0
# trait_Finesse_Shot                                                                       0
# trait_Solid_Player                                                                       0
# has_release_clause                                                                      No
# Name: 101637, dtype: object
